# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input, Layer, Bidirectional
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/PLN_Timeseries/442100110323_hourly.csv')
df['READ_DATE'] = pd.to_datetime(df['READ_DATE'])
df.set_index('READ_DATE', inplace=True)
df
# Out:
#                        KWH_EXP
# READ_DATE
# 2019-01-01 00:00:00   2.402650
# 2019-01-01 01:00:00   2.408348
# 2019-01-01 02:00:00   2.406840
# 2019-01-01 03:00:00   2.256511
# 2019-01-01 04:00:00   2.065598
# ...                        ...
# 2024-05-31 19:00:00  65.205495
# 2024-05-31 20:00:00  65.520523
# 2024-05-31 21:00:00  66.389436
# 2024-05-31 22:00:00  69.132420
# 2024-05-31 23:00:00  69.015896
#
# [47472 rows x 1 columns]

# %%
# split data train dan test. 3 tahun pertama untuk train, 2 tahun terakhir untuk test
train = df.loc['2019-01-01':'2022-12-31']
test = df.loc['2023-01-01':]

# %%
scaler = StandardScaler()

# %%
# scaling data train
train_scaled = scaler.fit_transform(train)
train_scaled = pd.DataFrame(train_scaled, columns=train.columns, index=train.index)
train_scaled
# Out:
#                       KWH_EXP
# READ_DATE
# 2019-01-01 00:00:00 -0.921600
# 2019-01-01 01:00:00 -0.920917
# 2019-01-01 02:00:00 -0.921098
# 2019-01-01 03:00:00 -0.939135
# 2019-01-01 04:00:00 -0.962042
# ...                       ...
# 2022-12-31 19:00:00 -0.891599
# 2022-12-31 20:00:00 -0.870325
# 2022-12-31 21:00:00 -0.870764
# 2022-12-31 22:00:00 -0.876849
# 2022-12-31 23:00:00 -0.865906
#
# [35064 rows x 1 columns]

# %%
# scaling data test
test_scaled = scaler.transform(test)
test_scaled = pd.DataFrame(test_scaled, columns=test.columns, index=test.index)
test_scaled
# Out:
#                       KWH_EXP
# READ_DATE
# 2023-01-01 00:00:00 -0.857399
# 2023-01-01 01:00:00 -0.865644
# 2023-01-01 02:00:00 -0.872474
# 2023-01-01 03:00:00 -0.869078
# 2023-01-01 04:00:00 -0.871847
# ...                       ...
# 2024-05-31 19:00:00  6.613860
# 2024-05-31 20:00:00  6.651659
# 2024-05-31 21:00:00  6.755916
# 2024-05-31 22:00:00  7.085036
# 2024-05-31 23:00:00  7.071054
#
# [12408 rows x 1 columns]

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
# jika datanya diambil setiap 15 menit, maka time_steps = 96 berarti 24 jam

time_steps = 96
# reshape ke bentuk 3D array
X_train, y_train = create_dataset(train_scaled, train_scaled['KWH_EXP'], time_steps)
X_test, y_test = create_dataset(test_scaled, test_scaled['KWH_EXP'], time_steps)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (34968, 96, 1) (34968,)
# (12312, 96, 1) (12312,)

# %%
model = Sequential()
model.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Bidirectional(LSTM(units=64, return_sequences=False)))
model.add(Dense(units=1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ (None, 96, 256)             │         133,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 297,601 (1.14 MB)
#  Trainable params: 297,601 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# SPLITTING DATA RATIO :
#
# * Train data : tahun 2019-2022 akhir
# * Test data : tahun 2023-ujung data
# * Validation data : diambil 10% dari training data

# %%
#  callback
# early stopping
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')
# learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * np.exp(-0.1)

lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# training
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_split=0.1,
    shuffle=False,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - loss: 0.3757 - val_loss: 0.0519 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.1134 - val_loss: 0.0415 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0956 - val_loss: 0.0357 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0815 - val_loss: 0.0327 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0738 - val_loss: 0.0335 - learning_rate: 0.0010
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0760 - val_loss: 0.0297 - learning_rate: 9.0484e-04
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0659 - val_loss: 0.0279 - learning_rate: 8.1873e-04
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0619 - val_loss: 0.0274 - learning_rate: 7.4082e-04
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0599 - val_loss: 0.0270 - learning_rate: 6.7032e-04
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0583 - val_loss: 0.0267 - learning_rate: 6.0653e-04
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0566 - val_loss: 0.0263 - learning_rate: 5.4881e-04
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0549 - val_loss: 0.0259 - learning_rate: 4.9659e-04
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0536 - val_loss: 0.0257 - learning_rate: 4.4933e-04
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0526 - val_loss: 0.0251 - learning_rate: 4.0657e-04
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0513 - val_loss: 0.0252 - learning_rate: 3.6788e-04
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0498 - val_loss: 0.0241 - learning_rate: 3.3287e-04
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0502 - val_loss: 0.0267 - learning_rate: 3.0119e-04
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0504 - val_loss: 0.0249 - learning_rate: 2.7253e-04
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0487 - val_loss: 0.0244 - learning_rate: 2.4660e-04
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0475 - val_loss: 0.0242 - learning_rate: 2.2313e-04
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0467 - val_loss: 0.0239 - learning_rate: 2.0190e-04
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0459 - val_loss: 0.0237 - learning_rate: 1.8268e-04
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0453 - val_loss: 0.0234 - learning_rate: 1.6530e-04
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0447 - val_loss: 0.0232 - learning_rate: 1.4957e-04
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0441 - val_loss: 0.0230 - learning_rate: 1.3534e-04
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0436 - val_loss: 0.0228 - learning_rate: 1.2246e-04
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0432 - val_loss: 0.0226 - learning_rate: 1.1080e-04
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0429 - val_loss: 0.0225 - learning_rate: 1.0026e-04
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0426 - val_loss: 0.0223 - learning_rate: 9.0718e-05
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0423 - val_loss: 0.0222 - learning_rate: 8.2085e-05
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0421 - val_loss: 0.0221 - learning_rate: 7.4274e-05
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0418 - val_loss: 0.0219 - learning_rate: 6.7206e-05
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0416 - val_loss: 0.0218 - learning_rate: 6.0810e-05
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0414 - val_loss: 0.0217 - learning_rate: 5.5023e-05
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0412 - val_loss: 0.0216 - learning_rate: 4.9787e-05
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0411 - val_loss: 0.0215 - learning_rate: 4.5049e-05
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0409 - val_loss: 0.0215 - learning_rate: 4.0762e-05
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0408 - val_loss: 0.0214 - learning_rate: 3.6883e-05
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0407 - val_loss: 0.0214 - learning_rate: 3.3373e-05
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0407 - val_loss: 0.0213 - learning_rate: 3.0197e-05
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0406 - val_loss: 0.0213 - learning_rate: 2.7324e-05
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 0.0405 - val_loss: 0.0213 - learning_rate: 2.4724e-05
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0405 - val_loss: 0.0212 - learning_rate: 2.2371e-05
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0404 - val_loss: 0.0212 - learning_rate: 2.0242e-05
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0404 - val_loss: 0.0211 - learning_rate: 1.8316e-05
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0403 - val_loss: 0.0211 - learning_rate: 1.6573e-05
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0403 - val_loss: 0.0211 - learning_rate: 1.4996e-05
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0402 - val_loss: 0.0210 - learning_rate: 1.3569e-05
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0402 - val_loss: 0.0210 - learning_rate: 1.2277e-05
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0401 - val_loss: 0.0210 - learning_rate: 1.1109e-05
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0401 - val_loss: 0.0210 - learning_rate: 1.0052e-05
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0401 - val_loss: 0.0210 - learning_rate: 9.0953e-06
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0400 - val_loss: 0.0210 - learning_rate: 8.2297e-06
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0400 - val_loss: 0.0210 - learning_rate: 7.4466e-06
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0400 - val_loss: 0.0210 - learning_rate: 6.7379e-06
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0400 - val_loss: 0.0210 - learning_rate: 6.0967e-06
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0400 - val_loss: 0.0210 - learning_rate: 5.5166e-06
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0400 - val_loss: 0.0209 - learning_rate: 4.9916e-06
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0400 - val_loss: 0.0209 - learning_rate: 4.5166e-06
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 4.0868e-06
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 3.6979e-06
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 3.3460e-06
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 3.0276e-06
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 2.7394e-06
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 2.4788e-06
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 2.2429e-06
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 2.0294e-06
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 1.8363e-06
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 1.6616e-06
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 1.5034e-06
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 1.3604e-06
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 1.2309e-06
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 1.1138e-06
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 1.0078e-06
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 9.1188e-07
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 8.2511e-07
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 7.4659e-07
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 6.7554e-07
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0399 - val_loss: 0.0209 - learning_rate: 6.1125e-07
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 5.5308e-07
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 5.0045e-07
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 4.5283e-07
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 4.0974e-07
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 3.7074e-07
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 3.3546e-07
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 3.0354e-07
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 2.7465e-07
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 2.4852e-07
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 2.2487e-07
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 2.0347e-07
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 1.8411e-07
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 1.6659e-07
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 1.5073e-07
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 1.3639e-07
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 1.2341e-07
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 1.1167e-07
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 1.0104e-07
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 9.1424e-08
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 8.2724e-08
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 7.4852e-08

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.show()

# %%
# predict

y_pred = model.predict(X_test)
y_pred = y_pred.reshape(-1)
y_test = y_test.reshape(-1)
# Out:
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, marker='.', label='Actual', color='blue', markersize=3)
plt.plot(y_pred, marker='x', label='Predicted', color='red', markersize=3)
plt.axhline(0, color='gray', linestyle='--')  # Garis referensi
plt.title('Actual vs Predicted KWH_EXP')
plt.xlabel('Time Steps')
plt.ylabel('KWH_EXP')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
print('MSE:', mean_squared_error(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R2:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MSE: 0.04393002490423027
# MAE: 0.08241473039137481
# R2: 0.975794351607107
# MAPE: 0.6296993337734665

# %% [markdown]
# # ATTENTION

# %%
# Define Attention Layer
class AttentionLayer(Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()

    def call(self, inputs):
        attention_weights = tf.nn.softmax(tf.matmul(inputs, inputs, transpose_b=True), axis=-1)
        context_vector = tf.matmul(attention_weights, inputs)
        return context_vector

# Model definition with Attention
input_shape = (X_train.shape[1], X_train.shape[2])
inputs = Input(shape=input_shape)
x = LSTM(units=128, return_sequences=True)(inputs)
x = AttentionLayer()(x)
x = LSTM(units=64, return_sequences=False)(x)
outputs = Dense(units=1)(x)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# Callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * np.exp(-0.1)

lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# Training the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_split=0.1,
    shuffle=False,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 96, 1)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 96, 128)             │          66,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ attention_layer (AttentionLayer)     │ (None, 96, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 116,033 (453.25 KB)
#  Trainable params: 116,033 (453.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.3915 - val_loss: 0.1033 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.2539 - val_loss: 0.0952 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.2404 - val_loss: 0.0936 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.2280 - val_loss: 0.0948 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.2213 - val_loss: 0.0834 - learning_rate: 0.0010
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1537 - val_loss: 0.0737 - learning_rate: 9.0484e-04
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1395 - val_loss: 0.0670 - learning_rate: 8.1873e-04
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1303 - val_loss: 0.0620 - learning_rate: 7.4082e-04
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1241 - val_loss: 0.0597 - learning_rate: 6.7032e-04
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1191 - val_loss: 0.0591 - learning_rate: 6.0653e-04
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1154 - val_loss: 0.0584 - learning_rate: 5.4881e-04
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1119 - val_loss: 0.0561 - learning_rate: 4.9659e-04
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1085 - val_loss: 0.0541 - learning_rate: 4.4933e-04
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1053 - val_loss: 0.0516 - learning_rate: 4.0657e-04
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1028 - val_loss: 0.0500 - learning_rate: 3.6788e-04
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1006 - val_loss: 0.0486 - learning_rate: 3.3287e-04
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0980 - val_loss: 0.0476 - learning_rate: 3.0119e-04
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0958 - val_loss: 0.0465 - learning_rate: 2.7253e-04
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0936 - val_loss: 0.0454 - learning_rate: 2.4660e-04
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0914 - val_loss: 0.0443 - learning_rate: 2.2313e-04
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0891 - val_loss: 0.0437 - learning_rate: 2.0190e-04
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0870 - val_loss: 0.0429 - learning_rate: 1.8268e-04
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0845 - val_loss: 0.0418 - learning_rate: 1.6530e-04
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0823 - val_loss: 0.0411 - learning_rate: 1.4957e-04
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0802 - val_loss: 0.0398 - learning_rate: 1.3534e-04
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0784 - val_loss: 0.0386 - learning_rate: 1.2246e-04
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0764 - val_loss: 0.0369 - learning_rate: 1.1080e-04
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0741 - val_loss: 0.0352 - learning_rate: 1.0026e-04
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0722 - val_loss: 0.0340 - learning_rate: 9.0718e-05
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0706 - val_loss: 0.0330 - learning_rate: 8.2085e-05
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0692 - val_loss: 0.0322 - learning_rate: 7.4274e-05
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0681 - val_loss: 0.0315 - learning_rate: 6.7206e-05
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0672 - val_loss: 0.0309 - learning_rate: 6.0810e-05
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0662 - val_loss: 0.0305 - learning_rate: 5.5023e-05
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0655 - val_loss: 0.0300 - learning_rate: 4.9787e-05
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0646 - val_loss: 0.0297 - learning_rate: 4.5049e-05
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0643 - val_loss: 0.0293 - learning_rate: 4.0762e-05
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0635 - val_loss: 0.0290 - learning_rate: 3.6883e-05
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0631 - val_loss: 0.0288 - learning_rate: 3.3373e-05
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0624 - val_loss: 0.0286 - learning_rate: 3.0197e-05
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0619 - val_loss: 0.0284 - learning_rate: 2.7324e-05
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0613 - val_loss: 0.0282 - learning_rate: 2.4724e-05
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0610 - val_loss: 0.0281 - learning_rate: 2.2371e-05
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0607 - val_loss: 0.0280 - learning_rate: 2.0242e-05
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0603 - val_loss: 0.0280 - learning_rate: 1.8316e-05
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0600 - val_loss: 0.0278 - learning_rate: 1.6573e-05
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0597 - val_loss: 0.0278 - learning_rate: 1.4996e-05
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0594 - val_loss: 0.0277 - learning_rate: 1.3569e-05
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0591 - val_loss: 0.0276 - learning_rate: 1.2277e-05
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0588 - val_loss: 0.0275 - learning_rate: 1.1109e-05
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0586 - val_loss: 0.0274 - learning_rate: 1.0052e-05
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0584 - val_loss: 0.0273 - learning_rate: 9.0953e-06
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0583 - val_loss: 0.0273 - learning_rate: 8.2297e-06
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0582 - val_loss: 0.0272 - learning_rate: 7.4466e-06
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0581 - val_loss: 0.0272 - learning_rate: 6.7379e-06
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0580 - val_loss: 0.0272 - learning_rate: 6.0967e-06
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0579 - val_loss: 0.0271 - learning_rate: 5.5166e-06
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0578 - val_loss: 0.0271 - learning_rate: 4.9916e-06
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0578 - val_loss: 0.0271 - learning_rate: 4.5166e-06
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0577 - val_loss: 0.0271 - learning_rate: 4.0868e-06
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0577 - val_loss: 0.0271 - learning_rate: 3.6979e-06
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0576 - val_loss: 0.0270 - learning_rate: 3.3460e-06
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0576 - val_loss: 0.0270 - learning_rate: 3.0276e-06
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0576 - val_loss: 0.0270 - learning_rate: 2.7394e-06
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0575 - val_loss: 0.0270 - learning_rate: 2.4788e-06
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0575 - val_loss: 0.0270 - learning_rate: 2.2429e-06
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0575 - val_loss: 0.0270 - learning_rate: 2.0294e-06
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0574 - val_loss: 0.0270 - learning_rate: 1.8363e-06
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0574 - val_loss: 0.0270 - learning_rate: 1.6616e-06
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0574 - val_loss: 0.0270 - learning_rate: 1.5034e-06
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0574 - val_loss: 0.0270 - learning_rate: 1.3604e-06
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0574 - val_loss: 0.0270 - learning_rate: 1.2309e-06
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0270 - learning_rate: 1.1138e-06
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0270 - learning_rate: 1.0078e-06
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0270 - learning_rate: 9.1188e-07
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0269 - learning_rate: 8.2511e-07
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0269 - learning_rate: 7.4659e-07
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0269 - learning_rate: 6.7554e-07
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0269 - learning_rate: 6.1125e-07
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0269 - learning_rate: 5.5308e-07
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0269 - learning_rate: 5.0045e-07
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0573 - val_loss: 0.0269 - learning_rate: 4.5283e-07
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 4.0974e-07
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 3.7074e-07
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 3.3546e-07
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 3.0354e-07
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 2.7465e-07
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 2.4852e-07
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 2.2487e-07
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 2.0347e-07
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 1.8411e-07
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 1.6659e-07
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 1.5073e-07
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 1.3639e-07
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 1.2341e-07
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 1.1167e-07
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 1.0104e-07
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 9.1424e-08
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 8.2724e-08
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0572 - val_loss: 0.0269 - learning_rate: 7.4852e-08

# %%
# Plotting the loss
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss with Attention')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Predictions
y_pred = model.predict(X_test)
y_pred = y_pred.reshape(-1)
y_test = y_test.reshape(-1)
# Out:
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Actual vs Predicted plot
plt.figure(figsize=(12, 6))
plt.plot(y_test, marker='.', label='Actual', color='blue', markersize=3)
plt.plot(y_pred, marker='x', label='Predicted', color='red', markersize=3)
plt.axhline(0, color='gray', linestyle='--')  # Reference line
plt.title('Actual vs Predicted KWH_EXP with Attention')
plt.xlabel('Time Steps')
plt.ylabel('KWH_EXP')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Metrics
print('MSE:', mean_squared_error(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R²:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MSE: 0.23496754917406715
# MAE: 0.1483673436108188
# R²: 0.8705317856876612
# MAPE: 0.7280712286367884

# %% [markdown]
# BILSTM ATTENTION

# %%
# Define Attention Layer
class AttentionLayer(Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()

    def call(self, inputs):
        attention_weights = tf.nn.softmax(tf.matmul(inputs, inputs, transpose_b=True), axis=-1)
        context_vector = tf.matmul(attention_weights, inputs)
        return context_vector

# Model definition with Attention
input_shape = (X_train.shape[1], X_train.shape[2])
inputs = Input(shape=input_shape)
x = Bidirectional(LSTM(units=128, return_sequences=True))(inputs)
x = AttentionLayer()(x)
x = Bidirectional(LSTM(units=64, return_sequences=False))(x)
outputs = Dense(units=1)(x)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# Callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * np.exp(-0.1)

lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# Training the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_split=0.1,
    shuffle=False,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 96, 1)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_2 (Bidirectional)      │ (None, 96, 256)             │         133,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ attention_layer_1 (AttentionLayer)   │ (None, 96, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_3 (Bidirectional)      │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 297,601 (1.14 MB)
#  Trainable params: 297,601 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - loss: 0.4091 - val_loss: 0.1017 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.2593 - val_loss: 0.0910 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.2328 - val_loss: 0.0903 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.2184 - val_loss: 0.1000 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.2074 - val_loss: 0.0816 - learning_rate: 0.0010
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.1551 - val_loss: 0.0782 - learning_rate: 9.0484e-04
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.1640 - val_loss: 0.0756 - learning_rate: 8.1873e-04
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.1330 - val_loss: 0.0513 - learning_rate: 7.4082e-04
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.1087 - val_loss: 0.0509 - learning_rate: 6.7032e-04
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0997 - val_loss: 0.0473 - learning_rate: 6.0653e-04
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0928 - val_loss: 0.0443 - learning_rate: 5.4881e-04
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0860 - val_loss: 0.0405 - learning_rate: 4.9659e-04
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0825 - val_loss: 0.0395 - learning_rate: 4.4933e-04
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0753 - val_loss: 0.0421 - learning_rate: 4.0657e-04
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0783 - val_loss: 0.0358 - learning_rate: 3.6788e-04
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0691 - val_loss: 0.0338 - learning_rate: 3.3287e-04
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0659 - val_loss: 0.0332 - learning_rate: 3.0119e-04
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0642 - val_loss: 0.0328 - learning_rate: 2.7253e-04
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0631 - val_loss: 0.0325 - learning_rate: 2.4660e-04
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0620 - val_loss: 0.0322 - learning_rate: 2.2313e-04
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0610 - val_loss: 0.0318 - learning_rate: 2.0190e-04
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0601 - val_loss: 0.0313 - learning_rate: 1.8268e-04
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0591 - val_loss: 0.0307 - learning_rate: 1.6530e-04
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0582 - val_loss: 0.0303 - learning_rate: 1.4957e-04
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0575 - val_loss: 0.0298 - learning_rate: 1.3534e-04
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0568 - val_loss: 0.0293 - learning_rate: 1.2246e-04
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0562 - val_loss: 0.0289 - learning_rate: 1.1080e-04
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0556 - val_loss: 0.0286 - learning_rate: 1.0026e-04
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0550 - val_loss: 0.0283 - learning_rate: 9.0718e-05
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0545 - val_loss: 0.0281 - learning_rate: 8.2085e-05
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0541 - val_loss: 0.0279 - learning_rate: 7.4274e-05
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0537 - val_loss: 0.0278 - learning_rate: 6.7206e-05
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0533 - val_loss: 0.0277 - learning_rate: 6.0810e-05
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0530 - val_loss: 0.0276 - learning_rate: 5.5023e-05
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0527 - val_loss: 0.0275 - learning_rate: 4.9787e-05
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0525 - val_loss: 0.0273 - learning_rate: 4.5049e-05
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0522 - val_loss: 0.0271 - learning_rate: 4.0762e-05
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0520 - val_loss: 0.0269 - learning_rate: 3.6883e-05
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0517 - val_loss: 0.0268 - learning_rate: 3.3373e-05
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0515 - val_loss: 0.0267 - learning_rate: 3.0197e-05
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0513 - val_loss: 0.0266 - learning_rate: 2.7324e-05
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0511 - val_loss: 0.0265 - learning_rate: 2.4724e-05
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0510 - val_loss: 0.0264 - learning_rate: 2.2371e-05
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0508 - val_loss: 0.0263 - learning_rate: 2.0242e-05
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0507 - val_loss: 0.0263 - learning_rate: 1.8316e-05
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0506 - val_loss: 0.0262 - learning_rate: 1.6573e-05
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0505 - val_loss: 0.0262 - learning_rate: 1.4996e-05
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0504 - val_loss: 0.0262 - learning_rate: 1.3569e-05
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0503 - val_loss: 0.0261 - learning_rate: 1.2277e-05
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0503 - val_loss: 0.0261 - learning_rate: 1.1109e-05
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0502 - val_loss: 0.0261 - learning_rate: 1.0052e-05
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0501 - val_loss: 0.0261 - learning_rate: 9.0953e-06
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0501 - val_loss: 0.0260 - learning_rate: 8.2297e-06
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0500 - val_loss: 0.0260 - learning_rate: 7.4466e-06
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0500 - val_loss: 0.0260 - learning_rate: 6.7379e-06
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0499 - val_loss: 0.0260 - learning_rate: 6.0967e-06
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 0.0499 - val_loss: 0.0260 - learning_rate: 5.5166e-06
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0499 - val_loss: 0.0260 - learning_rate: 4.9916e-06
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0498 - val_loss: 0.0260 - learning_rate: 4.5166e-06
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0498 - val_loss: 0.0260 - learning_rate: 4.0868e-06
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0498 - val_loss: 0.0259 - learning_rate: 3.6979e-06
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0497 - val_loss: 0.0259 - learning_rate: 3.3460e-06
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0497 - val_loss: 0.0259 - learning_rate: 3.0276e-06
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0497 - val_loss: 0.0259 - learning_rate: 2.7394e-06
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0497 - val_loss: 0.0259 - learning_rate: 2.4788e-06
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0497 - val_loss: 0.0259 - learning_rate: 2.2429e-06
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0497 - val_loss: 0.0259 - learning_rate: 2.0294e-06
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 1.8363e-06
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 1.6616e-06
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 1.5034e-06
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 1.3604e-06
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 1.2309e-06
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 1.1138e-06
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 1.0078e-06
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 9.1188e-07
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 8.2511e-07
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 7.4659e-07
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 6.7554e-07
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0259 - learning_rate: 6.1125e-07
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 5.5308e-07
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 5.0045e-07
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 4.5283e-07
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 4.0974e-07
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 3.7074e-07
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 3.3546e-07
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 3.0354e-07
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 2.7465e-07
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 2.4852e-07
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 2.2487e-07
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 2.0347e-07
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 1.8411e-07
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 1.6659e-07
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 1.5073e-07
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 1.3639e-07
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0259 - learning_rate: 1.2341e-07
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0258 - learning_rate: 1.1167e-07
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0258 - learning_rate: 1.0104e-07
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0258 - learning_rate: 9.1424e-08
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0258 - learning_rate: 8.2724e-08
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0495 - val_loss: 0.0258 - learning_rate: 7.4852e-08

# %%
# Plotting the loss
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss with Attention')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Predictions
y_pred = model.predict(X_test)
y_pred = y_pred.reshape(-1)
y_test = y_test.reshape(-1)
# Out:
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step

# %%
# Actual vs Predicted plot
plt.figure(figsize=(12, 6))
plt.plot(y_test, marker='.', label='Actual', color='blue', markersize=3)
plt.plot(y_pred, marker='x', label='Predicted', color='red', markersize=3)
plt.axhline(0, color='gray', linestyle='--')  # Reference line
plt.title('Actual vs Predicted KWH_EXP with BILSTM Attention')
plt.xlabel('Time Steps')
plt.ylabel('KWH_EXP')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Metrics
print('MSE:', mean_squared_error(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R²:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MSE: 0.36288907528109837
# MAE: 0.16843747968670145
# R²: 0.8000464288143281
# MAPE: 0.7340304105446404

# %% [markdown]
# # LSTM

# %%
model = Sequential()
model.add(LSTM(units=128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dense(units=1))

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# Callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * np.exp(-0.1)

lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# Training the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_split=0.1,
    shuffle=False,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 96, 1)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_2 (Bidirectional)      │ (None, 96, 256)             │         133,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ attention_layer_1 (AttentionLayer)   │ (None, 96, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_3 (Bidirectional)      │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 297,601 (1.14 MB)
#  Trainable params: 297,601 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 0.0932 - val_loss: 0.0339 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0628 - val_loss: 0.0338 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0632 - val_loss: 0.0320 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0590 - val_loss: 0.0282 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0566 - val_loss: 0.0764 - learning_rate: 0.0010
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0899 - val_loss: 0.0711 - learning_rate: 9.0484e-04
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0723 - val_loss: 0.0269 - learning_rate: 8.1873e-04
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0530 - val_loss: 0.0257 - learning_rate: 7.4082e-04
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0510 - val_loss: 0.0250 - learning_rate: 6.7032e-04
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0502 - val_loss: 0.0246 - learning_rate: 6.0653e-04
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0498 - val_loss: 0.0244 - learning_rate: 5.4881e-04
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0496 - val_loss: 0.0243 - learning_rate: 4.9659e-04
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0494 - val_loss: 0.0243 - learning_rate: 4.4933e-04
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0487 - val_loss: 0.0243 - learning_rate: 4.0657e-04
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0479 - val_loss: 0.0243 - learning_rate: 3.6788e-04
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0474 - val_loss: 0.0241 - learning_rate: 3.3287e-04
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0468 - val_loss: 0.0241 - learning_rate: 3.0119e-04
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0464 - val_loss: 0.0241 - learning_rate: 2.7253e-04
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0460 - val_loss: 0.0240 - learning_rate: 2.4660e-04
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0456 - val_loss: 0.0239 - learning_rate: 2.2313e-04
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0452 - val_loss: 0.0239 - learning_rate: 2.0190e-04
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0449 - val_loss: 0.0238 - learning_rate: 1.8268e-04
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0447 - val_loss: 0.0238 - learning_rate: 1.6530e-04
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0444 - val_loss: 0.0238 - learning_rate: 1.4957e-04
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0442 - val_loss: 0.0238 - learning_rate: 1.3534e-04
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0440 - val_loss: 0.0238 - learning_rate: 1.2246e-04
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0438 - val_loss: 0.0238 - learning_rate: 1.1080e-04
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0436 - val_loss: 0.0238 - learning_rate: 1.0026e-04
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0435 - val_loss: 0.0238 - learning_rate: 9.0718e-05
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0433 - val_loss: 0.0237 - learning_rate: 8.2085e-05
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0432 - val_loss: 0.0237 - learning_rate: 7.4274e-05
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0431 - val_loss: 0.0237 - learning_rate: 6.7206e-05
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0429 - val_loss: 0.0236 - learning_rate: 6.0810e-05
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0428 - val_loss: 0.0236 - learning_rate: 5.5023e-05
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0427 - val_loss: 0.0236 - learning_rate: 4.9787e-05
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0426 - val_loss: 0.0236 - learning_rate: 4.5049e-05
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0426 - val_loss: 0.0235 - learning_rate: 4.0762e-05
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0425 - val_loss: 0.0235 - learning_rate: 3.6883e-05
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0424 - val_loss: 0.0234 - learning_rate: 3.3373e-05
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0424 - val_loss: 0.0233 - learning_rate: 3.0197e-05
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0423 - val_loss: 0.0233 - learning_rate: 2.7324e-05
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0422 - val_loss: 0.0232 - learning_rate: 2.4724e-05
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0422 - val_loss: 0.0232 - learning_rate: 2.2371e-05
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0422 - val_loss: 0.0232 - learning_rate: 2.0242e-05
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0421 - val_loss: 0.0231 - learning_rate: 1.8316e-05
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0421 - val_loss: 0.0231 - learning_rate: 1.6573e-05
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0420 - val_loss: 0.0231 - learning_rate: 1.4996e-05
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0420 - val_loss: 0.0230 - learning_rate: 1.3569e-05
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0420 - val_loss: 0.0230 - learning_rate: 1.2277e-05
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0420 - val_loss: 0.0230 - learning_rate: 1.1109e-05
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0419 - val_loss: 0.0230 - learning_rate: 1.0052e-05
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0419 - val_loss: 0.0230 - learning_rate: 9.0953e-06
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0419 - val_loss: 0.0230 - learning_rate: 8.2297e-06
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0419 - val_loss: 0.0230 - learning_rate: 7.4466e-06
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 6.7379e-06
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 6.0967e-06
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 5.5166e-06
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 4.9916e-06
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 4.5166e-06
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 4.0868e-06
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 3.6979e-06
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 3.3460e-06
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 3.0276e-06
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0418 - val_loss: 0.0229 - learning_rate: 2.7394e-06
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 2.4788e-06
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 2.2429e-06
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 2.0294e-06
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.8363e-06
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.6616e-06
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.5034e-06
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.3604e-06
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.2309e-06
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.1138e-06
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.0078e-06
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 9.1188e-07
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 8.2511e-07
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 7.4659e-07
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 6.7554e-07
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 6.1125e-07
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 5.5308e-07
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 5.0045e-07
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 4.5283e-07
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 4.0974e-07
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 3.7074e-07
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 3.3546e-07
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 3.0354e-07
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 2.7465e-07
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 2.4852e-07
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 2.2487e-07
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 2.0347e-07
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.8411e-07
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.6659e-07
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.5073e-07
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.3639e-07
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.2341e-07
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.1167e-07
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 1.0104e-07
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 9.1424e-08
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 8.2724e-08
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.0417 - val_loss: 0.0229 - learning_rate: 7.4852e-08

# %%
# Plotting the loss
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss with LSTM')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Predictions
y_pred = model.predict(X_test)
y_pred = y_pred.reshape(-1)
y_test = y_test.reshape(-1)
# Out:
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step

# %%
# Actual vs Predicted plot
plt.figure(figsize=(12, 6))
plt.plot(y_test, marker='.', label='Actual', color='blue', markersize=3)
plt.plot(y_pred, marker='x', label='Predicted', color='red', markersize=3)
plt.axhline(0, color='gray', linestyle='--')  # Reference line
plt.title('Actual vs Predicted KWH_EXP with LSTM')
plt.xlabel('Time Steps')
plt.ylabel('KWH_EXP')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Metrics
print('MSE:', mean_squared_error(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R²:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MSE: 0.2614128384126594
# MAE: 0.13803293279267492
# R²: 0.8559603081081872
# MAPE: 0.5754998682679658
