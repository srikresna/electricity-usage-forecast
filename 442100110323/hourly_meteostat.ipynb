# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_absolute_percentage_error

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input, Layer, Bidirectional
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/PLN_Timeseries/442100110323_hourly_meteostat.csv')
df['READ_DATE'] = pd.to_datetime(df['READ_DATE'])
df.drop('READ_DATE_day', axis=1, inplace=True)
df.set_index('READ_DATE', inplace=True)
df
# Out:
#                        KWH_EXP  temp  dwpt  rhum   wdir  wspd    pres  coco
# READ_DATE
# 2019-01-01 00:00:00   2.402650  26.1  25.2  95.0  140.0   5.4  1010.0   7.0
# 2019-01-01 01:00:00   2.408348  27.7  24.7  84.0  321.0   5.5  1009.8   7.0
# 2019-01-01 02:00:00   2.406840  28.7  24.7  79.0  329.0   7.4  1009.7   7.0
# 2019-01-01 03:00:00   2.256511  25.4  24.9  97.0  323.0   0.0  1010.1   7.0
# 2019-01-01 04:00:00   2.065598  29.5  25.0  77.0  327.0  11.1  1008.9   8.0
# ...                        ...   ...   ...   ...    ...   ...     ...   ...
# 2024-05-31 19:00:00  65.205495  28.2  23.1  74.0  150.0   9.4  1011.6   2.0
# 2024-05-31 20:00:00  65.520523  28.2  23.1  74.0  150.0   9.4  1011.6   2.0
# 2024-05-31 21:00:00  66.389436  28.2  23.1  74.0  150.0   9.4  1011.6   2.0
# 2024-05-31 22:00:00  69.132420  28.2  23.1  74.0  150.0   9.4  1011.6   2.0
# 2024-05-31 23:00:00  69.015896  28.2  23.1  74.0  150.0   9.4  1011.6   2.0
#
# [47472 rows x 8 columns]

# %%
# split data train dan test. 3 tahun pertama untuk train, 2 tahun terakhir untuk test
train = df.loc['2019-01-01':'2022-12-31']
test = df.loc['2023-01-01':]

# %%
scaler = StandardScaler()

# %%
# scaling data train
train_scaled = scaler.fit_transform(train)
train_scaled = pd.DataFrame(train_scaled, columns=train.columns, index=train.index)
train_scaled
# Out:
#                       KWH_EXP      temp      dwpt      rhum      wdir  \
# READ_DATE
# 2019-01-01 00:00:00 -0.921600 -0.466364  1.185728  1.343937 -0.420074
# 2019-01-01 01:00:00 -0.920917  0.074062  0.935136  0.514419  1.720327
# 2019-01-01 02:00:00 -0.921098  0.411829  0.935136  0.137365  1.814930
# 2019-01-01 03:00:00 -0.939135 -0.702801  1.035373  1.494759  1.743978
# 2019-01-01 04:00:00 -0.962042  0.682042  1.085491 -0.013457  1.791279
# ...                       ...       ...       ...       ...       ...
# 2022-12-31 19:00:00 -0.891599 -0.702801  0.584308  1.117705  1.377390
# 2022-12-31 20:00:00 -0.870325 -0.669024  0.534190  1.042294  1.436517
# 2022-12-31 21:00:00 -0.870764 -0.229928  0.634426  0.589829  1.590247
# 2022-12-31 22:00:00 -0.876849 -0.500141  0.684544  0.966883  1.483818
# 2022-12-31 23:00:00 -0.865906 -0.365034  0.734663  0.816062  1.460168
#
#                          wspd      pres      coco
# READ_DATE
# 2019-01-01 00:00:00 -0.741796  0.370252  0.708480
# 2019-01-01 01:00:00 -0.720198  0.268182  0.708480
# 2019-01-01 02:00:00 -0.309831  0.217147  0.708480
# 2019-01-01 03:00:00 -1.908102  0.421287  0.708480
# 2019-01-01 04:00:00  0.489305 -0.191132  0.927251
# ...                       ...       ...       ...
# 2022-12-31 19:00:00  0.899672 -0.956655  1.146022
# 2022-12-31 20:00:00  0.899672 -1.007690  1.146022
# 2022-12-31 21:00:00  2.519541 -0.650446  0.927251
# 2022-12-31 22:00:00  2.497943 -0.701481  0.708480
# 2022-12-31 23:00:00  1.698808 -0.446306  0.708480
#
# [35064 rows x 8 columns]

# %%
# scaling data test
test_scaled = scaler.transform(test)
test_scaled = pd.DataFrame(test_scaled, columns=test.columns, index=test.index)
test_scaled
# Out:
#                       KWH_EXP      temp      dwpt      rhum      wdir  \
# READ_DATE
# 2023-01-01 00:00:00 -0.857399 -0.061044  0.885018  0.589829  1.590247
# 2023-01-01 01:00:00 -0.865644  0.006509  0.885018  0.514419  1.519295
# 2023-01-01 02:00:00 -0.872474  0.276722  0.935136  0.288186  1.578422
# 2023-01-01 03:00:00 -0.869078  0.513159  1.085491  0.137365  1.708501
# 2023-01-01 04:00:00 -0.871847  0.546936  1.035373  0.061954  1.637549
# ...                       ...       ...       ...       ...       ...
# 2024-05-31 19:00:00  6.613860  0.242946  0.133243 -0.239689 -0.301820
# 2024-05-31 20:00:00  6.651659  0.242946  0.133243 -0.239689 -0.301820
# 2024-05-31 21:00:00  6.755916  0.242946  0.133243 -0.239689 -0.301820
# 2024-05-31 22:00:00  7.085036  0.242946  0.133243 -0.239689 -0.301820
# 2024-05-31 23:00:00  7.071054  0.242946  0.133243 -0.239689 -0.301820
#
#                          wspd      pres      coco
# READ_DATE
# 2023-01-01 00:00:00  3.297079  0.166112  0.708480
# 2023-01-01 01:00:00  1.288441 -0.191132  0.708480
# 2023-01-01 02:00:00  1.698808 -0.242167  0.708480
# 2023-01-01 03:00:00  3.297079 -0.191132  0.708480
# 2023-01-01 04:00:00  2.497943 -0.497341  0.708480
# ...                       ...       ...       ...
# 2024-05-31 19:00:00  0.122135  1.186810 -0.385377
# 2024-05-31 20:00:00  0.122135  1.186810 -0.385377
# 2024-05-31 21:00:00  0.122135  1.186810 -0.385377
# 2024-05-31 22:00:00  0.122135  1.186810 -0.385377
# 2024-05-31 23:00:00  0.122135  1.186810 -0.385377
#
# [12408 rows x 8 columns]

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
# jika datanya diambil setiap 1 jam maka timestep nya 24

time_steps = 24
# reshape ke bentuk 3D array
X_train, y_train = create_dataset(train_scaled, train_scaled['KWH_EXP'], time_steps)
X_test, y_test = create_dataset(test_scaled, test_scaled['KWH_EXP'], time_steps)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (35040, 24, 8) (35040,)
# (12384, 24, 8) (12384,)

# %%
model = Sequential()
model.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Bidirectional(LSTM(units=64, return_sequences=False)))
model.add(Dense(units=1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional_4 (Bidirectional)      │ (None, 24, 256)             │         140,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_5 (Bidirectional)      │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 304,769 (1.16 MB)
#  Trainable params: 304,769 (1.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# SPLITTING DATA RATIO :
#
# * Train data : tahun 2019-2022 akhir
# * Test data : tahun 2023-ujung data
# * Validation data : diambil 10% dari training data

# %%
#  callback
# early stopping
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')
# learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * np.exp(-0.1)

lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# training
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_split=0.1,
    shuffle=False,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.3901 - val_loss: 0.0528 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1128 - val_loss: 0.1056 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1119 - val_loss: 0.0366 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0798 - val_loss: 0.0329 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0754 - val_loss: 0.0337 - learning_rate: 0.0010
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0733 - val_loss: 0.0338 - learning_rate: 9.0484e-04
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0658 - val_loss: 0.0303 - learning_rate: 8.1873e-04
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0613 - val_loss: 0.0275 - learning_rate: 7.4082e-04
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0585 - val_loss: 0.0274 - learning_rate: 6.7032e-04
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0561 - val_loss: 0.0267 - learning_rate: 6.0653e-04
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0545 - val_loss: 0.0263 - learning_rate: 5.4881e-04
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0530 - val_loss: 0.0259 - learning_rate: 4.9659e-04
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0517 - val_loss: 0.0256 - learning_rate: 4.4933e-04
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0506 - val_loss: 0.0253 - learning_rate: 4.0657e-04
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0497 - val_loss: 0.0251 - learning_rate: 3.6788e-04
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0488 - val_loss: 0.0249 - learning_rate: 3.3287e-04
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0481 - val_loss: 0.0248 - learning_rate: 3.0119e-04
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0474 - val_loss: 0.0246 - learning_rate: 2.7253e-04
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0468 - val_loss: 0.0245 - learning_rate: 2.4660e-04
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0463 - val_loss: 0.0243 - learning_rate: 2.2313e-04
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0459 - val_loss: 0.0242 - learning_rate: 2.0190e-04
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0455 - val_loss: 0.0239 - learning_rate: 1.8268e-04
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0452 - val_loss: 0.0235 - learning_rate: 1.6530e-04
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0443 - val_loss: 0.0230 - learning_rate: 1.4957e-04
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0434 - val_loss: 0.0227 - learning_rate: 1.3534e-04
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0427 - val_loss: 0.0224 - learning_rate: 1.2246e-04
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0422 - val_loss: 0.0222 - learning_rate: 1.1080e-04
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0418 - val_loss: 0.0220 - learning_rate: 1.0026e-04
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0415 - val_loss: 0.0218 - learning_rate: 9.0718e-05
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0412 - val_loss: 0.0216 - learning_rate: 8.2085e-05
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0409 - val_loss: 0.0215 - learning_rate: 7.4274e-05
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0406 - val_loss: 0.0214 - learning_rate: 6.7206e-05
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0404 - val_loss: 0.0212 - learning_rate: 6.0810e-05
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0402 - val_loss: 0.0211 - learning_rate: 5.5023e-05
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0400 - val_loss: 0.0211 - learning_rate: 4.9787e-05
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0399 - val_loss: 0.0210 - learning_rate: 4.5049e-05
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0398 - val_loss: 0.0209 - learning_rate: 4.0762e-05
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0397 - val_loss: 0.0209 - learning_rate: 3.6883e-05
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0396 - val_loss: 0.0208 - learning_rate: 3.3373e-05
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0395 - val_loss: 0.0208 - learning_rate: 3.0197e-05
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0394 - val_loss: 0.0207 - learning_rate: 2.7324e-05
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0393 - val_loss: 0.0207 - learning_rate: 2.4724e-05
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0392 - val_loss: 0.0206 - learning_rate: 2.2371e-05
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0391 - val_loss: 0.0206 - learning_rate: 2.0242e-05
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0390 - val_loss: 0.0205 - learning_rate: 1.8316e-05
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0389 - val_loss: 0.0205 - learning_rate: 1.6573e-05
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0388 - val_loss: 0.0205 - learning_rate: 1.4996e-05
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0388 - val_loss: 0.0204 - learning_rate: 1.3569e-05
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0387 - val_loss: 0.0204 - learning_rate: 1.2277e-05
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0387 - val_loss: 0.0204 - learning_rate: 1.1109e-05
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0386 - val_loss: 0.0204 - learning_rate: 1.0052e-05
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0386 - val_loss: 0.0203 - learning_rate: 9.0953e-06
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0385 - val_loss: 0.0203 - learning_rate: 8.2297e-06
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0385 - val_loss: 0.0203 - learning_rate: 7.4466e-06
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0385 - val_loss: 0.0203 - learning_rate: 6.7379e-06
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0384 - val_loss: 0.0203 - learning_rate: 6.0967e-06
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0384 - val_loss: 0.0203 - learning_rate: 5.5166e-06
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0384 - val_loss: 0.0202 - learning_rate: 4.9916e-06
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0384 - val_loss: 0.0202 - learning_rate: 4.5166e-06
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0383 - val_loss: 0.0202 - learning_rate: 4.0868e-06
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0383 - val_loss: 0.0202 - learning_rate: 3.6979e-06
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0383 - val_loss: 0.0202 - learning_rate: 3.3460e-06
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0383 - val_loss: 0.0202 - learning_rate: 3.0276e-06
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0383 - val_loss: 0.0202 - learning_rate: 2.7394e-06
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0383 - val_loss: 0.0202 - learning_rate: 2.4788e-06
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0383 - val_loss: 0.0202 - learning_rate: 2.2429e-06
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 2.0294e-06
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.8363e-06
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.6616e-06
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.5034e-06
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.3604e-06
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.2309e-06
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.1138e-06
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.0078e-06
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 9.1188e-07
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 8.2511e-07
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 7.4659e-07
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 6.7554e-07
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 6.1125e-07
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 5.5308e-07
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 5.0045e-07
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 4.5283e-07
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 4.0974e-07
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 3.7074e-07
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 3.3546e-07
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 3.0354e-07
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 2.7465e-07
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 2.4852e-07
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 2.2487e-07
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 2.0347e-07
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.8411e-07
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.6659e-07
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.5073e-07
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.3639e-07
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.2341e-07
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.1167e-07
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 1.0104e-07
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 9.1424e-08
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 8.2724e-08
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0382 - val_loss: 0.0202 - learning_rate: 7.4852e-08

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train')
plt.plot   (history.history['val_loss'], label='validation')
plt.legend()
plt.show()

# %%
# predict

y_pred = model.predict(X_test)
y_pred = y_pred.reshape(-1)
y_test = y_test.reshape(-1)
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, marker='.', label='Actual', color='blue', markersize=3)
plt.plot(y_pred, marker='x', label='Predicted', color='red', markersize=3)
plt.axhline(0, color='gray', linestyle='--')  # Garis referensi
plt.title('Actual vs Predicted KWH_EXP')
plt.xlabel('Time Steps')
plt.ylabel('KWH_EXP')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
print('MSE:', mean_squared_error(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R2:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MSE: 0.040616787336729666
# MAE: 0.08887661673568557
# R2: 0.9775365842689896
# MAPE: 0.7498028124256046

# %% [markdown]
# # ATTENTION

# %%
# Define Attention Layer
class AttentionLayer(Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()

    def call(self, inputs):
        attention_weights = tf.nn.softmax(tf.matmul(inputs, inputs, transpose_b=True), axis=-1)
        context_vector = tf.matmul(attention_weights, inputs)
        return context_vector

# Model definition with Attention
input_shape = (X_train.shape[1], X_train.shape[2])
inputs = Input(shape=input_shape)
x = LSTM(units=128, return_sequences=True)(inputs)
x = AttentionLayer()(x)
x = LSTM(units=64, return_sequences=False)(x)
outputs = Dense(units=1)(x)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# Callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * np.exp(-0.1)

lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# Training the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_split=0.1,
    shuffle=False,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 24, 8)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_10 (LSTM)                       │ (None, 24, 128)             │          70,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ attention_layer_2 (AttentionLayer)   │ (None, 24, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_11 (LSTM)                       │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 119,617 (467.25 KB)
#  Trainable params: 119,617 (467.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4975 - val_loss: 0.1057 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2501 - val_loss: 0.0714 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1767 - val_loss: 0.0689 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1631 - val_loss: 0.0601 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1476 - val_loss: 0.0635 - learning_rate: 0.0010
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1457 - val_loss: 0.0550 - learning_rate: 9.0484e-04
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1267 - val_loss: 0.0548 - learning_rate: 8.1873e-04
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1203 - val_loss: 0.0533 - learning_rate: 7.4082e-04
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1139 - val_loss: 0.0524 - learning_rate: 6.7032e-04
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1092 - val_loss: 0.0511 - learning_rate: 6.0653e-04
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1053 - val_loss: 0.0496 - learning_rate: 5.4881e-04
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1019 - val_loss: 0.0484 - learning_rate: 4.9659e-04
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0992 - val_loss: 0.0476 - learning_rate: 4.4933e-04
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0968 - val_loss: 0.0470 - learning_rate: 4.0657e-04
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0945 - val_loss: 0.0465 - learning_rate: 3.6788e-04
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0924 - val_loss: 0.0463 - learning_rate: 3.3287e-04
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0906 - val_loss: 0.0460 - learning_rate: 3.0119e-04
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0893 - val_loss: 0.0455 - learning_rate: 2.7253e-04
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0885 - val_loss: 0.0443 - learning_rate: 2.4660e-04
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0873 - val_loss: 0.0432 - learning_rate: 2.2313e-04
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0851 - val_loss: 0.0427 - learning_rate: 2.0190e-04
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0829 - val_loss: 0.0425 - learning_rate: 1.8268e-04
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0810 - val_loss: 0.0422 - learning_rate: 1.6530e-04
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0792 - val_loss: 0.0419 - learning_rate: 1.4957e-04
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0775 - val_loss: 0.0415 - learning_rate: 1.3534e-04
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0759 - val_loss: 0.0411 - learning_rate: 1.2246e-04
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0744 - val_loss: 0.0407 - learning_rate: 1.1080e-04
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0731 - val_loss: 0.0403 - learning_rate: 1.0026e-04
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0718 - val_loss: 0.0399 - learning_rate: 9.0718e-05
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0707 - val_loss: 0.0396 - learning_rate: 8.2085e-05
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0698 - val_loss: 0.0393 - learning_rate: 7.4274e-05
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0689 - val_loss: 0.0390 - learning_rate: 6.7206e-05
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0682 - val_loss: 0.0388 - learning_rate: 6.0810e-05
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0676 - val_loss: 0.0385 - learning_rate: 5.5023e-05
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0670 - val_loss: 0.0384 - learning_rate: 4.9787e-05
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0664 - val_loss: 0.0382 - learning_rate: 4.5049e-05
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0658 - val_loss: 0.0381 - learning_rate: 4.0762e-05
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0653 - val_loss: 0.0380 - learning_rate: 3.6883e-05
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0648 - val_loss: 0.0379 - learning_rate: 3.3373e-05
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0644 - val_loss: 0.0378 - learning_rate: 3.0197e-05
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0641 - val_loss: 0.0376 - learning_rate: 2.7324e-05
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0637 - val_loss: 0.0375 - learning_rate: 2.4724e-05
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0634 - val_loss: 0.0374 - learning_rate: 2.2371e-05
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0632 - val_loss: 0.0373 - learning_rate: 2.0242e-05
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0629 - val_loss: 0.0372 - learning_rate: 1.8316e-05
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0627 - val_loss: 0.0372 - learning_rate: 1.6573e-05
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0625 - val_loss: 0.0371 - learning_rate: 1.4996e-05
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0624 - val_loss: 0.0370 - learning_rate: 1.3569e-05
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0622 - val_loss: 0.0370 - learning_rate: 1.2277e-05
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0620 - val_loss: 0.0369 - learning_rate: 1.1109e-05
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0619 - val_loss: 0.0369 - learning_rate: 1.0052e-05
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0618 - val_loss: 0.0368 - learning_rate: 9.0953e-06
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0617 - val_loss: 0.0368 - learning_rate: 8.2297e-06
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0616 - val_loss: 0.0367 - learning_rate: 7.4466e-06
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0615 - val_loss: 0.0367 - learning_rate: 6.7379e-06
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0614 - val_loss: 0.0367 - learning_rate: 6.0967e-06
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0613 - val_loss: 0.0366 - learning_rate: 5.5166e-06
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0612 - val_loss: 0.0366 - learning_rate: 4.9916e-06
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0612 - val_loss: 0.0366 - learning_rate: 4.5166e-06
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0611 - val_loss: 0.0366 - learning_rate: 4.0868e-06
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0611 - val_loss: 0.0365 - learning_rate: 3.6979e-06
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0610 - val_loss: 0.0365 - learning_rate: 3.3460e-06
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0610 - val_loss: 0.0365 - learning_rate: 3.0276e-06
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0609 - val_loss: 0.0365 - learning_rate: 2.7394e-06
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0609 - val_loss: 0.0365 - learning_rate: 2.4788e-06
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0609 - val_loss: 0.0365 - learning_rate: 2.2429e-06
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0608 - val_loss: 0.0365 - learning_rate: 2.0294e-06
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0608 - val_loss: 0.0365 - learning_rate: 1.8363e-06
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0608 - val_loss: 0.0364 - learning_rate: 1.6616e-06
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0608 - val_loss: 0.0364 - learning_rate: 1.5034e-06
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0607 - val_loss: 0.0364 - learning_rate: 1.3604e-06
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0607 - val_loss: 0.0364 - learning_rate: 1.2309e-06
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0607 - val_loss: 0.0364 - learning_rate: 1.1138e-06
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0607 - val_loss: 0.0364 - learning_rate: 1.0078e-06
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0607 - val_loss: 0.0364 - learning_rate: 9.1188e-07
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0607 - val_loss: 0.0364 - learning_rate: 8.2511e-07
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 7.4659e-07
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 6.7554e-07
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 6.1125e-07
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 5.5308e-07
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 5.0045e-07
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 4.5283e-07
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 4.0974e-07
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 3.7074e-07
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 3.3546e-07
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 3.0354e-07
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 2.7465e-07
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 2.4852e-07
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 2.2487e-07
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 2.0347e-07
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 1.8411e-07
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 1.6659e-07
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 1.5073e-07
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 1.3639e-07
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 1.2341e-07
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 1.1167e-07
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0606 - val_loss: 0.0364 - learning_rate: 1.0104e-07
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0605 - val_loss: 0.0364 - learning_rate: 9.1424e-08
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0605 - val_loss: 0.0364 - learning_rate: 8.2724e-08
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0605 - val_loss: 0.0364 - learning_rate: 7.4852e-08

# %%
# Plotting the loss
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss with Attention')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Predictions
y_pred = model.predict(X_test)
y_pred = y_pred.reshape(-1)
y_test = y_test.reshape(-1)
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Actual vs Predicted plot
plt.figure(figsize=(12, 6))
plt.plot(y_test, marker='.', label='Actual', color='blue', markersize=3)
plt.plot(y_pred, marker='x', label='Predicted', color='red', markersize=3)
plt.axhline(0, color='gray', linestyle='--')  # Reference line
plt.title('Actual vs Predicted KWH_EXP with Attention')
plt.xlabel('Time Steps')
plt.ylabel('KWH_EXP')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Metrics
print('MSE:', mean_squared_error(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R²:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MSE: 0.14328640348980964
# MAE: 0.1484408398130712
# R²: 0.9207543909490294
# MAPE: 0.9613528631634821

# %% [markdown]
# BILSTM ATTENTION

# %%
# Define Attention Layer
class AttentionLayer(Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()

    def call(self, inputs):
        attention_weights = tf.nn.softmax(tf.matmul(inputs, inputs, transpose_b=True), axis=-1)
        context_vector = tf.matmul(attention_weights, inputs)
        return context_vector

# Model definition with Attention
input_shape = (X_train.shape[1], X_train.shape[2])
inputs = Input(shape=input_shape)
x = Bidirectional(LSTM(units=128, return_sequences=True))(inputs)
x = AttentionLayer()(x)
x = Bidirectional(LSTM(units=64, return_sequences=False))(x)
outputs = Dense(units=1)(x)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# Callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * np.exp(-0.1)

lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# Training the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_split=0.1,
    shuffle=False,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)           │ (None, 24, 8)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_6 (Bidirectional)      │ (None, 24, 256)             │         140,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ attention_layer_3 (AttentionLayer)   │ (None, 24, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_7 (Bidirectional)      │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 304,769 (1.16 MB)
#  Trainable params: 304,769 (1.16 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 0.3849 - val_loss: 0.1449 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1986 - val_loss: 0.1025 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1574 - val_loss: 0.0600 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1257 - val_loss: 0.0514 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1063 - val_loss: 0.0534 - learning_rate: 0.0010
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0907 - val_loss: 0.0412 - learning_rate: 9.0484e-04
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0798 - val_loss: 0.0376 - learning_rate: 8.1873e-04
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0742 - val_loss: 0.0364 - learning_rate: 7.4082e-04
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0725 - val_loss: 0.0344 - learning_rate: 6.7032e-04
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0670 - val_loss: 0.0329 - learning_rate: 6.0653e-04
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0637 - val_loss: 0.0328 - learning_rate: 5.4881e-04
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0634 - val_loss: 0.0322 - learning_rate: 4.9659e-04
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0616 - val_loss: 0.0326 - learning_rate: 4.4933e-04
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0603 - val_loss: 0.0323 - learning_rate: 4.0657e-04
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0586 - val_loss: 0.0332 - learning_rate: 3.6788e-04
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0583 - val_loss: 0.0321 - learning_rate: 3.3287e-04
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0557 - val_loss: 0.0314 - learning_rate: 3.0119e-04
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0542 - val_loss: 0.0311 - learning_rate: 2.7253e-04
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0531 - val_loss: 0.0310 - learning_rate: 2.4660e-04
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0520 - val_loss: 0.0307 - learning_rate: 2.2313e-04
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0508 - val_loss: 0.0304 - learning_rate: 2.0190e-04
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0497 - val_loss: 0.0302 - learning_rate: 1.8268e-04
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0487 - val_loss: 0.0299 - learning_rate: 1.6530e-04
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0477 - val_loss: 0.0297 - learning_rate: 1.4957e-04
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0467 - val_loss: 0.0295 - learning_rate: 1.3534e-04
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0459 - val_loss: 0.0295 - learning_rate: 1.2246e-04
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0452 - val_loss: 0.0294 - learning_rate: 1.1080e-04
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0446 - val_loss: 0.0293 - learning_rate: 1.0026e-04
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0442 - val_loss: 0.0292 - learning_rate: 9.0718e-05
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0437 - val_loss: 0.0292 - learning_rate: 8.2085e-05
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0434 - val_loss: 0.0291 - learning_rate: 7.4274e-05
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0430 - val_loss: 0.0291 - learning_rate: 6.7206e-05
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0427 - val_loss: 0.0290 - learning_rate: 6.0810e-05
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0425 - val_loss: 0.0290 - learning_rate: 5.5023e-05
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0422 - val_loss: 0.0290 - learning_rate: 4.9787e-05
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0420 - val_loss: 0.0289 - learning_rate: 4.5049e-05
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0419 - val_loss: 0.0288 - learning_rate: 4.0762e-05
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0417 - val_loss: 0.0288 - learning_rate: 3.6883e-05
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0415 - val_loss: 0.0287 - learning_rate: 3.3373e-05
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0413 - val_loss: 0.0286 - learning_rate: 3.0197e-05
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0412 - val_loss: 0.0285 - learning_rate: 2.7324e-05
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0410 - val_loss: 0.0284 - learning_rate: 2.4724e-05
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0409 - val_loss: 0.0283 - learning_rate: 2.2371e-05
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0408 - val_loss: 0.0282 - learning_rate: 2.0242e-05
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0407 - val_loss: 0.0282 - learning_rate: 1.8316e-05
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0406 - val_loss: 0.0281 - learning_rate: 1.6573e-05
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0405 - val_loss: 0.0281 - learning_rate: 1.4996e-05
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0404 - val_loss: 0.0280 - learning_rate: 1.3569e-05
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0403 - val_loss: 0.0280 - learning_rate: 1.2277e-05
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0402 - val_loss: 0.0280 - learning_rate: 1.1109e-05
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0402 - val_loss: 0.0280 - learning_rate: 1.0052e-05
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0401 - val_loss: 0.0279 - learning_rate: 9.0953e-06
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0400 - val_loss: 0.0279 - learning_rate: 8.2297e-06
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0400 - val_loss: 0.0279 - learning_rate: 7.4466e-06
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0400 - val_loss: 0.0279 - learning_rate: 6.7379e-06
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0399 - val_loss: 0.0279 - learning_rate: 6.0967e-06
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0399 - val_loss: 0.0279 - learning_rate: 5.5166e-06
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0399 - val_loss: 0.0279 - learning_rate: 4.9916e-06
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0398 - val_loss: 0.0279 - learning_rate: 4.5166e-06
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0398 - val_loss: 0.0279 - learning_rate: 4.0868e-06
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0398 - val_loss: 0.0279 - learning_rate: 3.6979e-06
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0398 - val_loss: 0.0279 - learning_rate: 3.3460e-06
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0397 - val_loss: 0.0279 - learning_rate: 3.0276e-06
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0397 - val_loss: 0.0278 - learning_rate: 2.7394e-06
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0397 - val_loss: 0.0278 - learning_rate: 2.4788e-06
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0397 - val_loss: 0.0278 - learning_rate: 2.2429e-06
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0397 - val_loss: 0.0278 - learning_rate: 2.0294e-06
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0397 - val_loss: 0.0278 - learning_rate: 1.8363e-06
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.6616e-06
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.5034e-06
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.3604e-06
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.2309e-06
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.1138e-06
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.0078e-06
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 9.1188e-07
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 8.2511e-07
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 7.4659e-07
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 6.7554e-07
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 6.1125e-07
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 5.5308e-07
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 5.0045e-07
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 4.5283e-07
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 4.0974e-07
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 3.7074e-07
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 3.3546e-07
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 3.0354e-07
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 2.7465e-07
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 2.4852e-07
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 2.2487e-07
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 2.0347e-07
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.8411e-07
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.6659e-07
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.5073e-07
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.3639e-07
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.2341e-07
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0396 - val_loss: 0.0278 - learning_rate: 1.1167e-07
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0395 - val_loss: 0.0278 - learning_rate: 1.0104e-07
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0395 - val_loss: 0.0278 - learning_rate: 9.1424e-08
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0395 - val_loss: 0.0278 - learning_rate: 8.2724e-08
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0395 - val_loss: 0.0278 - learning_rate: 7.4852e-08

# %%
# Plotting the loss
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss with Attention')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Predictions
y_pred = model.predict(X_test)
y_pred = y_pred.reshape(-1)
y_test = y_test.reshape(-1)
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Actual vs Predicted plot
plt.figure(figsize=(12, 6))
plt.plot(y_test, marker='.', label='Actual', color='blue', markersize=3)
plt.plot(y_pred, marker='x', label='Predicted', color='red', markersize=3)
plt.axhline(0, color='gray', linestyle='--')  # Reference line
plt.title('Actual vs Predicted KWH_EXP with BILSTM Attention')
plt.xlabel('Time Steps')
plt.ylabel('KWH_EXP')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Metrics
print('MSE:', mean_squared_error(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R²:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MSE: 0.053496910844174274
# MAE: 0.1090358427574318
# R²: 0.9704131363553028
# MAPE: 0.9111017733393879

# %% [markdown]
# # LSTM

# %%
model = Sequential()
model.add(LSTM(units=128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dense(units=1))

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()

# Callbacks
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, mode='min')

# Learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * np.exp(-0.1)

lr_scheduler = keras.callbacks.LearningRateScheduler(scheduler)

# Training the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=512,
    validation_split=0.1,
    shuffle=False,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)           │ (None, 24, 8)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_6 (Bidirectional)      │ (None, 24, 256)             │         140,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ attention_layer_3 (AttentionLayer)   │ (None, 24, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_7 (Bidirectional)      │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 304,769 (1.16 MB)
#  Trainable params: 304,769 (1.16 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0666 - val_loss: 0.0634 - learning_rate: 0.0010
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0863 - val_loss: 0.0453 - learning_rate: 0.0010
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0649 - val_loss: 0.0388 - learning_rate: 0.0010
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0558 - val_loss: 0.0393 - learning_rate: 0.0010
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0578 - val_loss: 0.0378 - learning_rate: 0.0010
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0574 - val_loss: 0.0340 - learning_rate: 9.0484e-04
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0515 - val_loss: 0.0301 - learning_rate: 8.1873e-04
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0471 - val_loss: 0.0302 - learning_rate: 7.4082e-04
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0473 - val_loss: 0.0315 - learning_rate: 6.7032e-04
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0450 - val_loss: 0.0284 - learning_rate: 6.0653e-04
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0426 - val_loss: 0.0294 - learning_rate: 5.4881e-04
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0411 - val_loss: 0.0273 - learning_rate: 4.9659e-04
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0400 - val_loss: 0.0273 - learning_rate: 4.4933e-04
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0386 - val_loss: 0.0275 - learning_rate: 4.0657e-04
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0377 - val_loss: 0.0275 - learning_rate: 3.6788e-04
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0372 - val_loss: 0.0270 - learning_rate: 3.3287e-04
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0368 - val_loss: 0.0266 - learning_rate: 3.0119e-04
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0363 - val_loss: 0.0263 - learning_rate: 2.7253e-04
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0357 - val_loss: 0.0261 - learning_rate: 2.4660e-04
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0353 - val_loss: 0.0259 - learning_rate: 2.2313e-04
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0349 - val_loss: 0.0257 - learning_rate: 2.0190e-04
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0346 - val_loss: 0.0255 - learning_rate: 1.8268e-04
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0344 - val_loss: 0.0255 - learning_rate: 1.6530e-04
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0341 - val_loss: 0.0254 - learning_rate: 1.4957e-04
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0339 - val_loss: 0.0253 - learning_rate: 1.3534e-04
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0336 - val_loss: 0.0252 - learning_rate: 1.2246e-04
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0334 - val_loss: 0.0252 - learning_rate: 1.1080e-04
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0332 - val_loss: 0.0252 - learning_rate: 1.0026e-04
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0330 - val_loss: 0.0252 - learning_rate: 9.0718e-05
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0328 - val_loss: 0.0252 - learning_rate: 8.2085e-05
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0326 - val_loss: 0.0252 - learning_rate: 7.4274e-05
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0325 - val_loss: 0.0252 - learning_rate: 6.7206e-05
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0324 - val_loss: 0.0252 - learning_rate: 6.0810e-05
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0322 - val_loss: 0.0251 - learning_rate: 5.5023e-05
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0321 - val_loss: 0.0251 - learning_rate: 4.9787e-05
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0320 - val_loss: 0.0250 - learning_rate: 4.5049e-05
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0319 - val_loss: 0.0249 - learning_rate: 4.0762e-05
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0318 - val_loss: 0.0248 - learning_rate: 3.6883e-05
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0317 - val_loss: 0.0247 - learning_rate: 3.3373e-05
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0316 - val_loss: 0.0246 - learning_rate: 3.0197e-05
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0316 - val_loss: 0.0245 - learning_rate: 2.7324e-05
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0315 - val_loss: 0.0244 - learning_rate: 2.4724e-05
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0314 - val_loss: 0.0244 - learning_rate: 2.2371e-05
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0314 - val_loss: 0.0243 - learning_rate: 2.0242e-05
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0313 - val_loss: 0.0243 - learning_rate: 1.8316e-05
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0313 - val_loss: 0.0243 - learning_rate: 1.6573e-05
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0312 - val_loss: 0.0242 - learning_rate: 1.4996e-05
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0312 - val_loss: 0.0242 - learning_rate: 1.3569e-05
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0311 - val_loss: 0.0242 - learning_rate: 1.2277e-05
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0311 - val_loss: 0.0242 - learning_rate: 1.1109e-05
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0311 - val_loss: 0.0241 - learning_rate: 1.0052e-05
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0310 - val_loss: 0.0241 - learning_rate: 9.0953e-06
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0310 - val_loss: 0.0241 - learning_rate: 8.2297e-06
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0310 - val_loss: 0.0241 - learning_rate: 7.4466e-06
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0310 - val_loss: 0.0241 - learning_rate: 6.7379e-06
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0309 - val_loss: 0.0241 - learning_rate: 6.0967e-06
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0309 - val_loss: 0.0241 - learning_rate: 5.5166e-06
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0309 - val_loss: 0.0241 - learning_rate: 4.9916e-06
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0309 - val_loss: 0.0241 - learning_rate: 4.5166e-06
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0309 - val_loss: 0.0241 - learning_rate: 4.0868e-06
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0309 - val_loss: 0.0241 - learning_rate: 3.6979e-06
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0309 - val_loss: 0.0241 - learning_rate: 3.3460e-06
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 3.0276e-06
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 2.7394e-06
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 2.4788e-06
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 2.2429e-06
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 2.0294e-06
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 1.8363e-06
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 1.6616e-06
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 1.5034e-06
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 1.3604e-06
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 1.2309e-06
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 1.1138e-06
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 1.0078e-06
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 9.1188e-07
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 8.2511e-07
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 7.4659e-07
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 6.7554e-07
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 6.1125e-07
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 5.5308e-07
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 5.0045e-07
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 4.5283e-07
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 4.0974e-07
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 3.7074e-07
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 3.3546e-07
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 3.0354e-07
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 2.7465e-07
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0308 - val_loss: 0.0240 - learning_rate: 2.4852e-07
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 2.2487e-07
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 2.0347e-07
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 1.8411e-07
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 1.6659e-07
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 1.5073e-07
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 1.3639e-07
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 1.2341e-07
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 1.1167e-07
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 1.0104e-07
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 9.1424e-08
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 8.2724e-08
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0307 - val_loss: 0.0240 - learning_rate: 7.4852e-08

# %%
# Plotting the loss
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss with LSTM')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# Predictions
y_pred = model.predict(X_test)
y_pred = y_pred.reshape(-1)
y_test = y_test.reshape(-1)
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Actual vs Predicted plot
plt.figure(figsize=(12, 6))
plt.plot(y_test, marker='.', label='Actual', color='blue', markersize=3)
plt.plot(y_pred, marker='x', label='Predicted', color='red', markersize=3)
plt.axhline(0, color='gray', linestyle='--')  # Reference line
plt.title('Actual vs Predicted KWH_EXP with LSTM')
plt.xlabel('Time Steps')
plt.ylabel('KWH_EXP')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Metrics
print('MSE:', mean_squared_error(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R²:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MSE: 0.08750791584972069
# MAE: 0.11250659993206859
# R²: 0.9516030975766282
# MAPE: 0.7194103966649581
